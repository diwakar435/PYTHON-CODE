# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# create a list of word

# %%
text = ("Artificial Intelligence (AI) refers to the ability of machines to perform tasks that typically require human intelligence. This involves processes like learning, reasoning, problem-solving, understanding natural language, and perceiving sensory inputs like images or sounds.")

# %%
text
# Out:
# 'Artificial Intelligence (AI) refers to the ability of machines to perform tasks that typically require human intelligence. This involves processes like learning, reasoning, problem-solving, understanding natural language, and perceiving sensory inputs like images or sounds.'

# %%
# create a wordcloud object 
wordcloud = WordCloud(width=420, height=200, margin=2, background_color='black', colormap='Accent',mode = 'RGBA').generate(text)

# %%
# display the generated image
plt.imshow(wordcloud, interpolation='quadric')
plt.axis('off')
plt.margins(x=0,y=0)
plt.show()
